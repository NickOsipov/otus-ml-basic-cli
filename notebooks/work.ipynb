# %%
def model(x, k=2, b=0):
    return k * x + b

# %%
input_data = [1, 2, 3, 4, 5]
output_data = [model(x, b=10) for x in input_data]

print("Input Data:", input_data)
print("Output Data:", output_data)
# Out:
# Input Data: [1, 2, 3, 4, 5]
# Output Data: [12, 14, 16, 18, 20]
